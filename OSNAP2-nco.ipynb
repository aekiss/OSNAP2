# %% [markdown]
# # OSNAP part 2 data extraction using NCO
#
# NB: uses deprecated cosima cookbook - needs
# ```
# module use /g/data/hh5/public/modules
# module load conda/analysis3-unstable
# ```

# %%
# %matplotlib inline
import cosima_cookbook as cc
import numpy as np
import pandas as pd
import xarray as xr
import flox  # for faster groupby in xarray with dask
from dask.distributed import Client
from datetime import timedelta, date
import calendar
import os
import shutil
import glob
from collections import OrderedDict
import subprocess
import warnings
import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)
logging.getLogger('distributed.utils_perf').setLevel(logging.ERROR)

# %%
import climtas.nci
climtas.nci.GadiClient(malloc_trim_threshold='64kib')
# Out:
# <Client: 'tcp://127.0.0.1:41285' processes=28 threads=28, memory=252.00 GiB>

# %%
session = cc.database.create_session()

# %% [markdown]
# ## Initialise data structure and define helper functions

# %%
# WARNING! FORGETS ALL LOADED DATA!
data = OrderedDict() # init nested dict of experiments and their analyses

# %%
def addexpt(k, d):
    if k in data:
        print('skipped {}: already exists'.format(k))
    else:
        data[k] = d

# %%
def dictget(d, l):
    """
    Get item in nested dict using a list of keys

    d: nested dict
    l: list of keys
    """
    if len(l) == 1:
        return d[l[0]]
    return dictget(d[l[0]], l[1:])

# %%
def dictknown(d, l):
    """
    Return true if list of keys is valid in nested dict

    d: nested dict
    l: list of keys
    """    
    while len(l)>0 and l[0] in d:
        d = d[l[0]]
        l = l[1:]
    return len(l) == 0

# %%
def dictput(d, l, item):
    """
    Put item in nested dict using a list of keys

    d: nested dict
    l: list of keys
    item: item to be put
    """
    while l[0] in d and len(l)>1:  # transerse existing keys
        d = d[l[0]]
        l = l[1:]
    while len(l)>1:  # add new keys as needed
        d[l[0]] = dict()
        d = d[l[0]]
        l = l[1:]
    d[l[0]] = item
    return

# %%
# convenience functions
def dget(l):
    return dictget(data, l)
def dknown(l):
    return dictknown(data, l)
def dput(l, item):
    return dictput(data, l, item)

# %%
def showdata():
    """
    Display structure of data
    """
    for k, d in data.items():
        print(k)
        for k2, d2 in d.items():
            print('  ', k2)
            try:
                for k3, d3 in d2.items():
                    print('    ', k3)
                    try:
                        for k4, d4 in d3.items():
                            print('      ', k4)
                            try:
                                for k5, d5 in d4.items():
                                    print('        ', k5)
                                    try:
                                        for k6, d6 in d5.items():
                                            print('          ', k6)
                                    except:
                                        pass
                            except:
                                pass
                    except:
                        pass
            except:
                pass

# %% [markdown]
# ## Set experiments, regions, date ranges, variables, frequencies etc
# 1deg_jra55_iaf_omip2_cycle6
#
# 1deg_jra55_iaf_omip2_cycle6_jra55v150_extension
#
# 025deg_jra55_iaf_omip2_cycle6
#
# 025deg_jra55_iaf_omip2_cycle6_jra55v150_extension
#
# 01deg_jra55v140_iaf_cycle4
#
# 01deg_jra55v140_iaf_cycle4_jra55v150_extension

# %%
addexpt('1', {'model':'access-om2',
              'expts': ['1deg_jra55_iaf_omip2_cycle6',
                        '1deg_jra55_iaf_omip2_cycle6_jra55v150_extension'],
              'gridfix': '/g/data/ik11/grids/ocean_grid_10.nc',
            # 'gridpaths': ['/g/data/ik11/grids/ocean_grid_10.nc']
              'gridpaths': []
             })

# %%
addexpt('025', {'model':'access-om2-025',
                'expts': ['025deg_jra55_iaf_omip2_cycle6',
                          '025deg_jra55_iaf_omip2_cycle6_jra55v150_extension'],
                'gridfix': '/g/data/ik11/grids/ocean_grid_025.nc',
                # 'gridpaths': ['/g/data/ik11/grids/ocean_grid_025.nc']
                'gridpaths': []
               })

# %%
addexpt('01', {'model':'access-om2-01',
               'expts': ['01deg_jra55v140_iaf_cycle4',
                         '01deg_jra55v140_iaf_cycle4_jra55v150_extension'],
               'gridfix': '/g/data/ik11/grids/ocean_grid_01.nc', 
               'gridpaths': [#'/g/data/ik11/grids/ocean_grid_01.nc', 
                             '/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_t.nc',
                             '/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_u.nc']
              })

# %%
showdata()
# Out:
# 1
#    model
#    expts
#    gridfix
#    gridpaths
# 025
#    model
#    expts
#    gridfix
#    gridpaths
# 01
#    model
#    expts
#    gridfix
#    gridpaths

# %%
# set date range

tstart = pd.to_datetime('1958', format='%Y')
# tend = pd.to_datetime('2023-01-01', format='%Y-%m-%d')
tend = pd.to_datetime('2023', format='%Y')
# tend = tstart + pd.DateOffset(years=30)
timerange = slice(tstart, tend)
firstyear = pd.to_datetime(tstart).year  # assumes tstart is 1 January!
lastyear = pd.to_datetime(tend).year-1  # assumes tend is 1 January!
yearrange = str(firstyear)+'-'+str(lastyear)
print('yearrange =', yearrange, 'complete years')
print('tstart =', tstart)
print('tend =', tend)
# Out:
# yearrange = 1958-2022 complete years
# tstart = 1958-01-01 00:00:00
# tend = 2023-01-01 00:00:00

# %% [markdown]
# Fred email 10 July 2025
# > we would like the same variable we previously received from you, i.e. hfds, wfo, thetao, so, and siconc, over a larger region (85˚W-25˚E 45˚N-85˚N).
#
# Fred email 28 May
# >   hfds - total surface heat fluxes into the ocean
#
#
# `'net_sfc_heating' + 'frazil_3d_int_z'`,  Net surface heat flux into ocean is net_sfc_heating + frazil_3d_int_z: https://github.com/COSIMA/access-om2/issues/139#issuecomment-639278547 and https://forum.access-hive.org.au/t/net-surface-heat-and-freshwater-flux-variables/993/2
#
#
#
# >   wfo - total surface freshwater fluxes into the ocean (under OMIP protocol this includes precipitation, evaporation, runoff, and fluxes due to sea ice changes)
#
# so is this just `pme_river`, ie that already includes sea ice water fluxes? see https://docs.google.com/document/d/1gdfU-yDVOl2O6c4LoAno2rNHhWW7LqfI1_4bIS6GPSI
#
# >
# >   siconc - sea ice concentration (sea ice is not required for WMF but Taydra is interested to look at potential links between bias in sea ice coverage and WMF)
#
#
# `aice_m`
#
# thetao - Sea Water Potential Temperature
# `pot_temp`
#
# so - Sea Water Salinity
# `salt`
#
# CF conventions - see https://cfconventions.org/Data/cf-standard-names/current/build/cf-standard-name-table.html
#
# # what about salt fluxes from ice and restoring?

# %%
varnames = [
    'salt','u',
            'net_sfc_heating', 'frazil_3d_int_z',  # hfds; Net surface heat flux into ocean is net_sfc_heating + frazil_3d_int_z: https://github.com/COSIMA/access-om2/issues/139#issuecomment-639278547 and heat: https://forum.access-hive.org.au/t/net-surface-heat-and-freshwater-flux-variables/993/2
            'pme_river',  # wfo; water
            'pot_temp',  # thetao
            'salt',  # so
            'aice_m',  # siconc
    # remainder weren't requested for OSNAP2
            'u', 'v',
            'pot_rho_0', 'pot_rho_2',
            'sea_level',
            'sfc_salt_flux_ice', 'sfc_salt_flux_restore',  # salt
    # ------- not provided in first OSNAP
            # 'mh_flux',  # sea ice melt
            # 'sfc_hflux_coupler',
            # 'sfc_hflux_from_runoff',
            # 'sfc_hflux_pme',
            # 'swflx',
            # 'lw_heat',
            # 'sens_heat',
            # 'evap_heat',
            # 'fprec_melt_heat',
           ]

# %% [raw]
# varnames = [
#             'u', 'v',
#             'pot_temp',
#             'sea_level'
#            ]

# %% [raw]
# varnames = []

# %% [raw]
# varnames = [ # vars needed for calculating dzt, dzu
#             'salt',
#             'u'
#             ]

# %%
tgriddims = ['xt_ocean', 'yt_ocean']
ugriddims = ['xu_ocean', 'yu_ocean']
tgridvars = ['geolon_t', 'geolat_t', 'area_t', 'dxt', 'dyt', 'ht']
ugridvars = ['geolon_c', 'geolat_c', 'area_u', 'dxu', 'dyu', 'hu']
gridvars = tgridvars+ugridvars+tgriddims+ugriddims

# %%
frequencies = ['1 monthly']

# %%
# Fred email 10 July 2025
# we would like the same variable we previously received from you ...
# over a larger region (85˚W-25˚E 45˚N-85˚N).                                                                                                                            
regions = OrderedDict([
    # ('NA', {'lon': slice(-70, 0), 'lat': slice(40, 70)}),  # original request for the North Atlantic: 70W-0E, 40N-70N
    # ('NAextended', {'lon': slice(-85, 25), 'lat': slice(45, 85)}),  # OSNAP2 request, naively specified by 1d coords
    ('NAextended', {'lon': slice(-85, 25), 'lat': slice(45, 99)}),  # OSNAP2 request, extended northward to account for grid distortion 
])

# %% [markdown]
# ## Calculations

# %% [markdown]
# ### Load data

# %%
def loadalldata(data, regions, freqs, varnames, gridvars, timerange=timerange, ncfiles=None):
    region = 'global'
    reduction = 'unreduced'

    varnames = list(set(varnames))

    if not isinstance(ncfiles, list):
        ncfiles = [ncfiles]*len(varnames)  # use the same ncfile for all variables

    for expt in data.keys():
        print(expt)
        for freq in freqs:
            kkey = [expt, region, freq, reduction]
            for varname, ncfile in zip(varnames, ncfiles):
                if not dknown(kkey+[varname]):
                    if ncfile is None:
                        print('loading', varname)
                    else:
                        print('loading', varname, 'from', ncfile)
                    ds1 = cc.querying.getvar(dget([expt, 'expts'])[0], varname, session, frequency=freq, ncfile=ncfile, decode_coords=False, start_time=str(timerange.start))
                    ds2 = cc.querying.getvar(dget([expt, 'expts'])[1], varname, session, frequency=freq, ncfile=ncfile, decode_coords=False, end_time=str(timerange.stop))
                    dscombined = xr.concat([ds1, ds2], 'time').sel(time=timerange)
                    dscombined.attrs['ncfiles'] = ds1.attrs['ncfiles'] + ds2.attrs['ncfiles']
                    dscombined.attrs['description'] = [ds1.attrs['description'], ds2.attrs['description']]
                    try:
                        dscombined.attrs['notes'] = [ds1.attrs['notes'], ds2.attrs['notes']]
                    except KeyError:
                        pass
                    dput(kkey+[varname], dscombined)

        freq = 'static'

        # first look for grid data in gridpaths (to avoid NaNs)
        grids = [(p, xr.open_dataset(p, chunks='auto')) for p in dget([expt, 'gridpaths'])]
        for k in gridvars:
            kkey = [expt, region, freq, k]
            if not dknown(kkey):
                for (p, g) in grids:
                    try:
                        dput(kkey, g[k])
                        da = g[k]
                        print(k, 'loaded from', p)
                        break
                    except:
                        continue
                try:
                    da = da.rename({'grid_x_T': 'xt_ocean', 'grid_y_T': 'yt_ocean'}) # fix for 01deg
                    da.coords['xt_ocean'] = dget(kkey[0:-1]+['xt_ocean']).values
                    da.coords['yt_ocean'] = dget(kkey[0:-1]+['yt_ocean']).values
                    dput(kkey, da)
                except:
                    pass
                try:
                    da = da.rename({'grid_x_C': 'xu_ocean', 'grid_y_C': 'yu_ocean'}) # fix for 01deg
                    da.coords['xu_ocean'] = dget(kkey[0:-1]+['xu_ocean']).values
                    da.coords['yu_ocean'] = dget(kkey[0:-1]+['yu_ocean']).values
                    dput(kkey, da)
                except:
                    pass

        # then try to find any missing grid data via cookbook database (will have NaNs for land tiles)
        for k in gridvars:
            kkey = [expt, region, freq, k]
            if not dknown(kkey):
                try:
                    da = cc.querying.getvar(dget([expt, 'expts'])[0], k, session, frequency='static', decode_coords=False, n=1)
                    dput(kkey, da)
                    print(k, 'loaded from', da.attrs['ncfiles'][0])
                except:
                    pass

# %%
# %%time
loadalldata(data, regions, frequencies, varnames, gridvars, timerange=timerange, ncfiles=None)
# Out:
# 1
# loading sfc_salt_flux_ice
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# loading salt
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# loading aice_m
# loading pme_river
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# loading net_sfc_heating
# loading sfc_salt_flux_restore
# loading pot_rho_2
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yt_ocean" starting at index 150. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xt_ocean" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "xu_ocean" starting at index 120. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/utils.py:77: UserWarning: The specified chunks separate the stored chunks along dimension "yu_ocean" starting at index 108. This could degrade performance. Instead, consider rechunking after loading.
#   return func(*args, **kwargs)
# loading u
# loading frazil_3d_int_z
# loading pot_rho_0
# geolon_t loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# geolat_t loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# area_t loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# dxt loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# dyt loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# ht loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# geolon_c loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# geolat_c loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# area_u loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# dxu loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# dyu loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# hu loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# xt_ocean loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# yt_ocean loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# xu_ocean loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# yu_ocean loaded from /g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle6/output305/ocean/ocean_grid.nc
# 01
# loading sfc_salt_flux_ice
# loading salt
# loading aice_m
# loading pme_river
# loading net_sfc_heating
# loading sfc_salt_flux_restore
# loading pot_rho_2
# loading sea_level
# loading pot_temp
# loading v
# loading u
# loading frazil_3d_int_z
# loading pot_rho_0
# area_t loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_t.nc
# area_u loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_u.nc
# xt_ocean loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_t.nc
# yt_ocean loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_t.nc
# xu_ocean loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_u.nc
# yu_ocean loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf/output000/ocean/ocean-2d-area_u.nc
# geolon_t loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output739/ocean/ocean-2d-geolon_t.nc
# geolat_t loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output938/ocean/ocean-2d-geolat_t.nc
# dxt loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output776/ocean/ocean-2d-dxt.nc
# dyt loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output857/ocean/ocean-2d-dyt.nc
# ht loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output777/ocean/ocean-2d-ht.nc
# geolon_c loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output921/ocean/ocean-2d-geolon_c.nc
# geolat_c loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output934/ocean/ocean-2d-geolat_c.nc
# dxu loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output890/ocean/ocean-2d-dxu.nc
# dyu loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output829/ocean/ocean-2d-dyu.nc
# hu loaded from /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle4/output796/ocean/ocean-2d-hu.nc
# CPU times: user 5min 3s, sys: 1min 16s, total: 6min 20s
# Wall time: 7min 5s

# %%
showdata()
# Out:
# 1
#    model
#    expts
#    gridfix
#    gridpaths
#    global
#      1 monthly
#        unreduced
#          sfc_salt_flux_ice
#          salt
#          aice_m
#          pme_river
#          net_sfc_heating
#          sfc_salt_flux_restore
#          pot_rho_2
#          sea_level
#          pot_temp
#          v
#          u
#          frazil_3d_int_z
#          pot_rho_0
#      static
#        geolon_t
#        geolat_t
#        area_t
#        dxt
#        dyt
#        ht
#        geolon_c
#        geolat_c
#        area_u
#        dxu
#        dyu
#        hu
#        xt_ocean
#        yt_ocean
#        xu_ocean
#        yu_ocean
# 025
#    model
#    expts
#    gridfix
#    gridpaths
#    global
#      1 monthly
#        unreduced
#          sfc_salt_flux_ice
#          salt
#          aice_m
#          pme_river
#          net_sfc_heating
#          sfc_salt_flux_restore
#          pot_rho_2
#          sea_level
#          pot_temp
#          v
#          u
#          frazil_3d_int_z
#          pot_rho_0
#      static
#        geolon_t
#        geolat_t
#        area_t
#        dxt
#        dyt
#        ht
#        geolon_c
#        geolat_c
#        area_u
#        dxu
#        dyu
#        hu
#        xt_ocean
#        yt_ocean
#        xu_ocean
#        yu_ocean
# 01
#    model
#    expts
#    gridfix
#    gridpaths
#    global
#      1 monthly
#        unreduced
#          sfc_salt_flux_ice
#          salt
#          aice_m
#          pme_river
#          net_sfc_heating
#          sfc_salt_flux_restore
#          pot_rho_2
#          sea_level
#          pot_temp
#          v
#          u
#          frazil_3d_int_z
#          pot_rho_0
#      static
#        area_t
#        area_u
#        xt_ocean
#        yt_ocean
#        xu_ocean
#        yu_ocean
#        geolon_t
#        geolat_t
#        dxt
#        dyt
#        ht
#        geolon_c
#        geolat_c
#        dxu
#        dyu
#        hu

# %% [markdown]
# ## Fix up processor masking in coords

# %%
freq = 'static'
for expt in data.keys():
    print(expt)
    for varname in ['geolon_t', 'geolat_t', 'geolon_c', 'geolat_c']:
        print(expt, varname)
        dget([expt,'global',freq,varname]).data = xr.open_dataset(dget([expt])['gridfix'])[varname].data
# Out:
# 1
# 1 geolon_t
# 1 geolat_t
# 1 geolon_c
# 1 geolat_c
# 025
# 025 geolon_t
# 025 geolat_t
# 025 geolon_c
# 025 geolat_c
# 01
# 01 geolon_t
# 01 geolat_t
# 01 geolon_c
# 01 geolat_c

# %% [markdown]
# ## Calculating dzt, dzu using data from `salt` and `u`
#
# These are the same (equal to diff of `st_edges_ocean`) except in the bottom partial cells.

# %%
basedir = '/g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/'

# %%
# %%time
freq = 'static'
for expt in data.keys():
    print(expt)
    for varname in ['dzt', 'dzu']:
        for region, region_data in regions.items():
            gvardir = os.path.join(basedir, 'global', freq, expt).replace(' ', '_')
            gvarf = os.path.join(gvardir, '-'.join(['access-om2', expt, varname])+'.nc')
            os.makedirs(gvardir, exist_ok=True)

            vardir = os.path.join(basedir, region, freq, expt).replace(' ', '_')
            varf = os.path.join(vardir, '-'.join(['access-om2', expt, varname])+'.nc')
            os.makedirs(vardir, exist_ok=True)
            
            st_ocean = dget([expt,'global','1 monthly','unreduced','salt']).st_ocean
            st_edges_ocean = cc.querying.getvar(dget([expt, 'expts'])[0], 'st_edges_ocean', session, frequency='1 monthly', n=1)
            
            dzt_1d = st_edges_ocean.diff('st_edges_ocean').assign_coords(st_edges_ocean=st_ocean.data).rename({'st_edges_ocean': 'st_ocean'})

            if varname == 'dzt':
                longname = 'tcell thickness'
                dzt = 0*dget([expt,'global','1 monthly','unreduced','salt']).isel(time=0) + dzt_1d
                
                kmt = cc.querying.getvar(dget([expt, 'expts'])[0], 'kmt', session, frequency='static', n=1).round().astype('int64')
                kmt = xr.where(kmt<0, 1, kmt).compute() - 1  # -1 to use zero-based indexing
    
                ht = dget([expt,'global','static','ht'])
                dzt_bottom = ht - st_edges_ocean[kmt]
    
            elif varname == 'dzu':  # (confusingly) keep same variable names as for t cells
                longname = 'ucell thickness'
                dzt = 0*dget([expt,'global','1 monthly','unreduced','u']).isel(time=0) + dzt_1d
                
                kmt = cc.querying.getvar(dget([expt, 'expts'])[0], 'kmu', session, frequency='static', n=1).round().astype('int64')
                kmt = xr.where(kmt<0, 1, kmt).compute() - 1  # -1 to use zero-based indexing
    
                ht = dget([expt,'global','static','hu'])
                dzt_bottom = ht - st_edges_ocean[kmt]
            else:
                raise ValueError('Bad varname: '+varname)

            dzt_fixed = xr.where(dzt.st_ocean!=dzt.st_ocean[kmt],
                     dzt,
                     dzt_bottom, # put partial cell height in bottom cells
                     keep_attrs=True).rename(varname)
            dzt_fixed = dzt_fixed.assign_attrs({'long_name': longname, 'units':'m'} | {k:ht.attrs[k] for k in ['contact', 'email', 'description', 'notes']})

            for k in tgridvars+ugridvars+['st_edges_ocean', 'time']:  # drop extraneous coords
                try:
                    dzt_fixed = dzt_fixed.drop_vars(k)
                except ValueError:
                    pass
            
            gds = dzt_fixed

# output global grid data
            if False: #os.path.exists(gvarf):
                print('--- skipped existing', gvarf)
                pass
            else:
                print('saving', gvarf)
                # gds.to_netcdf(gvarf+'-PARTIAL', encoding={"zlib": True, "complevel": 9} )
                gds.to_netcdf(gvarf+'-PARTIAL')
                os.rename(gvarf+'-PARTIAL', gvarf)

# extract spatial regions
            lons = ','.join([gds.dims[-1],
                                   repr(float(region_data['lon'].start)),
                                   repr(float(region_data['lon'].stop))])
            lats = ','.join([gds.dims[-2],
                                   repr(float(region_data['lat'].start)),
                                   repr(float(region_data['lat'].stop))])
            if False: #os.path.exists(varf):
                print('--- skipped existing', varf)
                pass
            else:
                cmd = ['ncks', '--deflate', '9', '-v', varname, '-d', lons, '-d', lats, '-O', gvarf, varf]
                print(' '.join(cmd))
                proc = subprocess.run(cmd)
# Out:
# 1
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dzt.nc
# ncks --deflate 9 -v dzt -d xt_ocean,-85.0,25.0 -d yt_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dzt.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dzt.nc
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dzu.nc
# ncks --deflate 9 -v dzu -d xu_ocean,-85.0,25.0 -d yu_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dzu.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dzu.nc
# 025
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dzt.nc
# ncks --deflate 9 -v dzt -d xt_ocean,-85.0,25.0 -d yt_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dzt.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dzt.nc
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dzu.nc
# ncks --deflate 9 -v dzu -d xu_ocean,-85.0,25.0 -d yu_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dzu.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dzu.nc
# 01
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dzt.nc
# ncks --deflate 9 -v dzt -d xt_ocean,-85.0,25.0 -d yt_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dzt.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dzt.nc
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/array/chunk.py:279: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# saving /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dzu.nc
# ncks --deflate 9 -v dzu -d xu_ocean,-85.0,25.0 -d yu_ocean,45.0,99.0 -O /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dzu.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dzu.nc
# CPU times: user 4min 28s, sys: 1min 51s, total: 6min 20s
# Wall time: 10min 26s

# %%
dzt_fixed.isel(yu_ocean=500).sel(xu_ocean=slice(-200,-100)).plot()

# %%
dzt_fixed.isel(st_ocean=kmt-1).plot()  # slow!

# %%
dzt_fixed.isel(st_ocean=kmt).plot()  # slow!

# %% [markdown]
# ## Get filenames to use with nco
#
# #### Regional subsetting:
# - https://nco.sourceforge.net/nco.html#ncks-netCDF-Kitchen-Sink
# - https://nco.sourceforge.net/nco.html#Hyperslabs-1 - use reals for coord values, integers for indices
# ```
# ncks -d xu_ocean,-70.0,0.0 -d yu_ocean,40.0,70.0 in.nc out.nc
# ```
# takes ~7sec per 1-month file at 0.1°
#
# Get in.nc from `dget(['01','global','1 monthly','unreduced','u']).attrs['ncfiles']`
#
# #### Concatenation in time:
# - https://nco.sourceforge.net/nco.html#Concatenation
# - https://nco.sourceforge.net/nco.html#ncrcat-netCDF-Record-Concatenator
# ```
# ncrcat in1.nc in2.nc ... inN.nc out.nc
# ```
# NB: inputs must be in chronological order!
#
# #### Trim in time:
# - https://nco.sourceforge.net/nco.html#Hyperslabs
#
# `ncfiles` list may contain more files than we need, so trim in time with `ncks`. Negative integer indices are offsets from the end, e.g. `-d time,,-2` drops the final time slice.
#
# - `for f in access-om2-1* ; do echo $f; ncdump -t -v time $f | grep 202[34]-; done` shows the 1deg data is already OK
#
# - `for f in access-om2-025* ; do echo $f; ncdump -t -v time $f | grep 202[34]-; done` shows 4 extra time slices in 0.25deg, so use `ncks -d time,,-5 in.nc out.nc` to trim them
# ```
#     "2023-01-14 12", "2023-02-13", "2023-03-14 12", "2023-04-14" ;
# ```
#
# - `for f in access-om2-01* ; do echo $f; ncdump -t -v time $f | grep 202[34]-; done` shows 1 extra time slice in 0.1deg, so use `ncks -d time,,-2 in.nc out.nc` to trim them
# ```
#     "2023-01-16 12" ;
# ```

# %%
# %%time
# extract and concatenate data for each region using nco
reduction = 'unreduced'
for expt in data.keys():
    for region, region_data in regions.items():
        for freq in frequencies:
            kkey = [expt, region, freq, reduction]
            for varname, vardata in dget([expt, 'global', freq, reduction]).items():
                vardir = os.path.join(basedir, region, freq, expt, varname).replace(' ', '_')
                os.makedirs(vardir, exist_ok=True)
                
                # extract spatial regions
                cice = '/ice/OUTPUT/' in vardata.attrs['ncfiles'][0] #data['1']['global']['1 monthly']['unreduced']['aice_m'].attrs['ncfiles'][0]
                if cice:
                    # cice output don't contain coord data, so need to slice by index, not coord value
# BUG: fails for data not on t-points
                    coord = dget([expt, 'global', 'static', 'xt_ocean'])
                    lonsarray = coord.sel(xt_ocean=region_data['lon']).values
                    lons = ','.join([vardata.dims[-1],
                                           repr(list(coord).index(lonsarray[0])),
                                           repr(list(coord).index(lonsarray[-1]))])
                    coord = dget([expt, 'global', 'static', 'yt_ocean'])
                    latsarray = coord.sel(yt_ocean=region_data['lat']).values
                    lats = ','.join([vardata.dims[-2],
                                           repr(list(coord).index(latsarray[0])),
                                           repr(list(coord).index(latsarray[-1]))])
                else:
                    lons = ','.join([vardata.dims[-1],
                                           repr(float(region_data['lon'].start)),
                                           repr(float(region_data['lon'].stop))])
                    lats = ','.join([vardata.dims[-2],
                                           repr(float(region_data['lat'].start)),
                                           repr(float(region_data['lat'].stop))])
                for count, nc in enumerate(vardata.attrs['ncfiles']):
                    if expt == '01':
                        outf = os.path.join(vardir, os.path.basename(nc))
                    else:
                        outf = os.path.join(vardir, '-'.join([varname, f'{count:04}']))
                    if os.path.exists(outf):
                        # print('--- skipped existing', outf)
                        pass
                    else:
                        cmd = ['ncks', '-v', varname, '-d', lons, '-d', lats, nc, outf]
                        # print(' '.join(cmd))
                        proc = subprocess.run(cmd)
    #                     break
                
                # concatenate in time
                outf = os.path.join(basedir, '-'.join(['access-om2', expt, varname])+'.nc')
                if os.path.exists(outf):
                    print('--- skipped existing', outf)
                else:
                    print(outf)
                    infiles = sorted(glob.glob(os.path.join(vardir, '*'))) #.sort()
                    cmd = ['ncrcat', *infiles, outf]
                    # print(' '.join(cmd))
                    proc = subprocess.run(cmd)
                    # break
                # break

                if cice:
# shift time back by 1 day if cice output https://github.com/COSIMA/cosima-recipes/blob/main/Recipes/Sea_Ice_Coordinates.ipynb
                    cmd = ['ncatted', '-a' "units,time,o,c,days since 1957-12-31", outf]
                    print(' '.join(cmd))
                    proc = subprocess.run(cmd)

                # trim in time
                tvardir = os.path.join(basedir, 'trimmed', '-'.join(['access-om2', expt]))
                os.makedirs(tvardir, exist_ok=True)
                toutf = os.path.join(tvardir, os.path.basename(outf))
                
                if os.path.exists(toutf):
                    print('--- skipped existing', toutf)
                else:
                    if expt == '01':
                        idx = -2
                    elif expt == '025':
                        if cice:
                            idx = -2
                        else:
                            idx = -5
                    else:
                        idx = None
    
                    if idx:
                        cmd = ['ncks', '-d', 'time,,'+str(idx), outf, toutf]
                        print(' '.join(cmd))
                        proc = subprocess.run(cmd)
                    else:
                        print('shutil.copy2({}, {})'.format(outf, toutf))
                        shutil.copy2(outf, toutf)
                    # break
    # break
# Out:
# /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/access-om2-1-sfc_salt_flux_ice.nc
# shutil.copy2(/g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/access-om2-1-sfc_salt_flux_ice.nc, /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/trimmed/access-om2-1/access-om2-1-sfc_salt_flux_ice.nc)
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/access-om2-1-salt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/trimmed/access-om2-1/access-om2-1-salt.nc

# %% [markdown]
# # NB: didn't use trimmed data, as ran into memory limits with 3d files - so ignore `trimmed` dir and share files from dir above

# %% [markdown]
# ~now check with~
# ```
# for f in trimmed/*/* ; do echo $f; ncdump -t -v time $f | grep 202[2-4]-; done
# ```
# ~and copy to globus with~
# ```
# rsync -vrltoD data-nco/trimmed/* /g/data/ik11/globus/osnap2-access-om2
# ```
#
# **copy to globus with**
# ```
# cd data-nco-new4
# rsync -vrltoD access-om2-* /g/data/ik11/globus/osnap2-access-om2
# rsync -vrltoD NAextended/static/*/access-om2-* /g/data/ik11/globus/osnap2-access-om2
# ```

# %% [markdown]
# ## Grid data

# %% [raw]
# # output global grid data
# region = 'global'
# freq = 'static'
# for expt in data.keys():
#     print(expt)
#     vardir = os.path.join(basedir, region, freq, expt).replace(' ', '_')
#     os.makedirs(vardir, exist_ok=True)
#     for varname in gridvars:
#         print(varname)
# # output global grid data
#         outf = os.path.join(vardir, '-'.join(['access-om2', expt, varname])+'.nc')
#         # print(outf)
#         if os.path.exists(outf):
#             print('--- skipped existing', outf)
#         else:
#             print('saving', outf)
#             dget([expt, region, freq, varname]).to_netcdf(outf+'-PARTIAL')
#             os.rename(outf+'-PARTIAL', outf)

# %%
# %%time
freq = 'static'
for expt in data.keys():
    for varname in tgridvars+ugridvars:
        for region, region_data in regions.items():
            gvardir = os.path.join(basedir, 'global', freq, expt).replace(' ', '_')
            gvarf = os.path.join(gvardir, '-'.join(['access-om2', expt, varname])+'.nc')
            os.makedirs(gvardir, exist_ok=True)
        
            vardir = os.path.join(basedir, region, freq, expt).replace(' ', '_')
            varf = os.path.join(vardir, '-'.join(['access-om2', expt, varname])+'.nc')
            os.makedirs(vardir, exist_ok=True)

            gds = dget([expt, 'global', freq, varname])

# output global grid data
            if os.path.exists(gvarf):
                print('--- skipped existing', gvarf)
                pass
            else:
                print('saving', gvarf)
                for k in tgridvars+ugridvars:  # drop extraneous coords
                    try:
                        gds = gds.drop_vars(k)
                    except ValueError:
                        pass
                gds.to_netcdf(gvarf+'-PARTIAL')
                os.rename(gvarf+'-PARTIAL', gvarf)

# extract spatial regions
            lons = ','.join([gds.dims[-1],
                                   repr(float(region_data['lon'].start)),
                                   repr(float(region_data['lon'].stop))])
            lats = ','.join([gds.dims[-2],
                                   repr(float(region_data['lat'].start)),
                                   repr(float(region_data['lat'].stop))])
            if os.path.exists(varf):
                print('--- skipped existing', varf)
                pass
            else:
                cmd = ['ncks', '-v', varname, '-d', lons, '-d', lats, gvarf, varf]
                print(' '.join(cmd))
                proc = subprocess.run(cmd)
# Out:
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-geolon_t.nc
# ncks -v geolon_t -d xt_ocean,-85.0,25.0 -d yt_ocean,45.0,99.0 /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-geolon_t.nc /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-geolon_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/1/access-om2-1-hu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-hu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-geolon_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-geolon_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/025/access-om2-025-hu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/025/access-om2-025-hu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-geolon_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-geolon_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-geolat_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-area_t.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dxt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dyt.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-ht.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-geolon_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-geolat_c.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-area_u.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dxu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-dyu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/global/static/01/access-om2-01-hu.nc
# --- skipped existing /g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/01/access-om2-01-hu.nc
# CPU times: user 31.3 ms, sys: 4.06 ms, total: 35.4 ms
# Wall time: 161 ms

# %% [markdown]
# ~copy to globus with~
# ```
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-1/grid
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-025/grid
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-01/grid
# ```
# ```
# rsync -vrltoD data-nco/NA/static/1/* /g/data/ik11/globus/osnap-access-om2/access-om2-1/grid
# rsync -vrltoD data-nco/NA/static/025/* /g/data/ik11/globus/osnap-access-om2/access-om2-025/grid
# rsync -vrltoD data-nco/NA/static/01/* /g/data/ik11/globus/osnap-access-om2/access-om2-01/grid
# ```

# %% [markdown]
# ~copy to globus with~
# ```
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-1/grid
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-025/grid
# mkdir -p /g/data/ik11/globus/osnap-access-om2/access-om2-01/grid
# ```
# ```
# rsync -vrltoD data-nco-new/NA/static/1/* /g/data/ik11/globus/osnap-access-om2/access-om2-1/grid
# rsync -vrltoD data-nco-new/NA/static/025/* /g/data/ik11/globus/osnap-access-om2/access-om2-025/grid
# rsync -vrltoD data-nco-new/NA/static/01/* /g/data/ik11/globus/osnap-access-om2/access-om2-01/grid
# ```

# %% [markdown]
# **copy to globus with**
# ```
# cd data-nco-new4
# rsync -vrltoD NAextended/static/*/access-om2-* /g/data/ik11/globus/osnap2-access-om2
# ```

# %%
geolon_test = xr.open_dataset('/g/data/v45/aek156/notebooks/github/aekiss/OSNAP2/data-nco-new4/NAextended/static/1/access-om2-1-geolon_t.nc')

# %%
geolon_test.geolon_t.plot()

# %% [markdown]
# ## Check fixed-up coords

# %%
freq = 'static'
for expt in data.keys():
    print(expt)
    for varname in ['geolon_t', 'geolat_t', 'geolon_c', 'geolat_c']:
        old = xr.open_dataset(basedir+'../data-nco/NA/static/'+expt+'/access-om2-'+expt+'-'+varname+'.nc')[varname].load()
        new = xr.open_dataset(basedir+'../data-nco-new2/NA/static/'+expt+'/access-om2-'+expt+'-'+varname+'.nc')[varname].load()
        diff = (old.data-new.data)
        print(expt, varname, diff.min(), diff.max())

# %%
old

# %%
new

# %%
old.data.dtype

# %%
new.data.dtype
